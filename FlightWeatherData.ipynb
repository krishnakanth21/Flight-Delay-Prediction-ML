# %%
import pandas as pd
from pandas import np

# %%
df = pd.read_csv(r"C:\Users\super\Downloads\2016\On_Time_On_Time_Performance_2016_1\On_Time_On_Time_Performance_2016_1.csv")
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (77) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate',
#        'UniqueCarrier', 'AirlineID', 'Carrier', 'TailNum',
#        ...
#        'Div4TailNum', 'Div5Airport', 'Div5AirportID', 'Div5AirportSeqID',
#        'Div5WheelsOn', 'Div5TotalGTime', 'Div5LongestGTime', 'Div5WheelsOff',
#        'Div5TailNum', 'Unnamed: 109'],
#       dtype='object', length=110)

# %%
df.dtypes
# Out:
# Year                    int64
# Quarter                 int64
# Month                   int64
# DayofMonth              int64
# DayOfWeek               int64
# FlightDate             object
# UniqueCarrier          object
# AirlineID               int64
# Carrier                object
# TailNum                object
# FlightNum               int64
# OriginAirportID         int64
# OriginAirportSeqID      int64
# OriginCityMarketID      int64
# Origin                 object
# OriginCityName         object
# OriginState            object
# OriginStateFips         int64
# OriginStateName        object
# OriginWac               int64
# DestAirportID           int64
# DestAirportSeqID        int64
# DestCityMarketID        int64
# Dest                   object
# DestCityName           object
# DestState              object
# DestStateFips           int64
# DestStateName          object
# DestWac                 int64
# CRSDepTime              int64
#                        ...
# ...

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2016        1      1           6          3  2016-01-06            AA
# 1  2016        1      1           7          4  2016-01-07            AA
# 2  2016        1      1           8          5  2016-01-08            AA
# 3  2016        1      1           9          6  2016-01-09            AA
# 4  2016        1      1          10          7  2016-01-10            AA
#
#    AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 0      19805      AA  N4YBAA      ...               NaN          NaN
# 1      19805      AA  N434AA      ...               NaN          NaN
# 2      19805      AA  N541AA      ...               NaN          NaN
# 3      19805      AA  N489AA      ...               NaN          NaN
# 4      19805      AA  N439AA      ...               NaN          NaN
#
#    Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# ...

# %%
df.values
# Out:
# array([[2016, 1, 1, ..., nan, nan, nan],
#        [2016, 1, 1, ..., nan, nan, nan],
#        [2016, 1, 1, ..., nan, nan, nan],
#        ...,
#        [2016, 1, 1, ..., nan, nan, nan],
#        [2016, 1, 1, ..., nan, nan, nan],
#        [2016, 1, 1, ..., nan, nan, nan]], dtype=object)

# %%
df.iloc[5:9]
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 5  2016        1      1          11          1  2016-01-11            AA
# 6  2016        1      1          12          2  2016-01-12            AA
# 7  2016        1      1          13          3  2016-01-13            AA
# 8  2016        1      1          14          4  2016-01-14            AA
#
#    AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 5      19805      AA  N468AA      ...               NaN          NaN
# 6      19805      AA  N4YBAA      ...               NaN          NaN
# 7      19805      AA  N569AA      ...               NaN          NaN
# 8      19805      AA  N466AA      ...               NaN          NaN
#
#    Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# 5            NaN               NaN          NaN            NaN
# 6            NaN               NaN          NaN            NaN
# ...

# %%
df.sort_values(by=['AirlineID'],ascending=True)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 270181  2016        1      1          12          2  2016-01-12            WN
# 299659  2016        1      1          22          5  2016-01-22            WN
# 299658  2016        1      1          22          5  2016-01-22            WN
# 299657  2016        1      1          22          5  2016-01-22            WN
# 299656  2016        1      1          22          5  2016-01-22            WN
# 299655  2016        1      1          22          5  2016-01-22            WN
# 299654  2016        1      1          22          5  2016-01-22            WN
# 299653  2016        1      1          22          5  2016-01-22            WN
# 299652  2016        1      1          22          5  2016-01-22            WN
# 299651  2016        1      1          22          5  2016-01-22            WN
# 299650  2016        1      1          22          5  2016-01-22            WN
# ...

# %%
df
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2016        1      1           6          3  2016-01-06            AA
# 1       2016        1      1           7          4  2016-01-07            AA
# 2       2016        1      1           8          5  2016-01-08            AA
# 3       2016        1      1           9          6  2016-01-09            AA
# 4       2016        1      1          10          7  2016-01-10            AA
# 5       2016        1      1          11          1  2016-01-11            AA
# 6       2016        1      1          12          2  2016-01-12            AA
# 7       2016        1      1          13          3  2016-01-13            AA
# 8       2016        1      1          14          4  2016-01-14            AA
# 9       2016        1      1          15          5  2016-01-15            AA
# 10      2016        1      1          16          6  2016-01-16            AA
# ...

# %%
df[df.AirlineID==19805]
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2016        1      1           6          3  2016-01-06            AA
# 1       2016        1      1           7          4  2016-01-07            AA
# 2       2016        1      1           8          5  2016-01-08            AA
# 3       2016        1      1           9          6  2016-01-09            AA
# 4       2016        1      1          10          7  2016-01-10            AA
# 5       2016        1      1          11          1  2016-01-11            AA
# 6       2016        1      1          12          2  2016-01-12            AA
# 7       2016        1      1          13          3  2016-01-13            AA
# 8       2016        1      1          14          4  2016-01-14            AA
# 9       2016        1      1          15          5  2016-01-15            AA
# 10      2016        1      1          16          6  2016-01-16            AA
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate',
#        'UniqueCarrier', 'AirlineID', 'Carrier', 'TailNum',
#        ...
#        'Div4TailNum', 'Div5Airport', 'Div5AirportID', 'Div5AirportSeqID',
#        'Div5WheelsOn', 'Div5TotalGTime', 'Div5LongestGTime', 'Div5WheelsOff',
#        'Div5TailNum', 'Unnamed: 109'],
#       dtype='object', length=110)

# %%
from datetime import datetime
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as pyplot

# %%
data = {'date': ['2014-05-01 18:47:05.069722', '2014-05-01 18:47:05.119994', '2014-05-02 18:47:05.178768', '2014-05-02 18:47:05.230071', '2014-05-02 18:47:05.230071', '2014-05-02 18:47:05.280592', '2014-05-03 18:47:05.332662', '2014-05-03 18:47:05.385109', '2014-05-04 18:47:05.436523', '2014-05-04 18:47:05.486877'], 
        'battle_deaths': [34, 25, 26, 15, 15, 14, 26, 25, 62, 41]}
df = pd.DataFrame(data, columns = ['date', 'battle_deaths'])
print(df)
# Out:
#                          date  battle_deaths
# 0  2014-05-01 18:47:05.069722             34
# 1  2014-05-01 18:47:05.119994             25
# 2  2014-05-02 18:47:05.178768             26
# 3  2014-05-02 18:47:05.230071             15
# 4  2014-05-02 18:47:05.230071             15
# 5  2014-05-02 18:47:05.280592             14
# 6  2014-05-03 18:47:05.332662             26
# 7  2014-05-03 18:47:05.385109             25
# 8  2014-05-04 18:47:05.436523             62
# 9  2014-05-04 18:47:05.486877             41

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.index=df['date']
del df['date']
df
# Out:
#                             battle_deaths
# date
# 2014-05-01 18:47:05.069722             34
# 2014-05-01 18:47:05.119994             25
# 2014-05-02 18:47:05.178768             26
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 18:47:05.280592             14
# 2014-05-03 18:47:05.332662             26
# 2014-05-03 18:47:05.385109             25
# 2014-05-04 18:47:05.436523             62
# 2014-05-04 18:47:05.486877             41

# %%
df['2014-05-03']
# Out:
#                             battle_deaths
# date
# 2014-05-03 18:47:05.332662             26
# 2014-05-03 18:47:05.385109             25

# %%
df[datetime(2014,5,3):]
# Out:
#                             battle_deaths
# date
# 2014-05-03 18:47:05.332662             26
# 2014-05-03 18:47:05.385109             25
# 2014-05-04 18:47:05.436523             62
# 2014-05-04 18:47:05.486877             41

# %%
df[datetime(2014,5,2):datetime(2014,5,4)]
# Out:
#                             battle_deaths
# date
# 2014-05-02 18:47:05.178768             26
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 18:47:05.280592             14
# 2014-05-03 18:47:05.332662             26
# 2014-05-03 18:47:05.385109             25

# %%
df['5/3/2014':'5/4/2014']
# Out:
#                             battle_deaths
# date
# 2014-05-03 18:47:05.332662             26
# 2014-05-03 18:47:05.385109             25
# 2014-05-04 18:47:05.436523             62
# 2014-05-04 18:47:05.486877             41

# %%
df.resample('D').sum().plot()

# %%
df.resample('D').mean().plot()

# %%
df.truncate(before='5/3/2014')
# Out:
#                             battle_deaths
# date
# 2014-05-03 18:47:05.332662             26
# 2014-05-03 18:47:05.385109             25
# 2014-05-04 18:47:05.436523             62
# 2014-05-04 18:47:05.486877             41

# %%
import json
import os
import glob
import fnmatch
from datetime import datetime

# %%
path=r'C:\Users\su per\Downloads\WeatherData\ATL\2016-3.json'
json_string=open(path).read()             #To read a json file as string from path 
json_object=json.loads(json_string)       #Decodes a JSON string into a JSON object

# %%
path1=r'C:\Users\super\Downloads\WeatherData'
df5=pd.DataFrame()
for i in os.listdir(path1):
      
       print(i)
      
       for j in os.listdir(path1 + '/' + i):
       
        if('2016' in j):
          print(j)    
          json_string=open(path1 + '/' + i + '/'+ j).read()             #To read a json file as string from path 
          d=json.loads(json_string)

          kk=json_normalize(d['data']['weather'])
          hourly_data=json_normalize(data=d['data']['weather'], record_path='hourly')
          hourly_data_new=hourly_data[['windspeedKmph','DewPointF','cloudcover','precipMM','pressure','WindGustKmph',
                             'visibility','weatherCode','tempF','WindChillF','winddirDegree','humidity','time']]
          
          kk1=json_normalize(d['data']['request'])
          airport_data=kk1[['query']] 
          hourly_data_new['Airport']=i
          date_data=kk[['date']]      
          date_range=pd.date_range(start=date_data['date'][0],periods=744,freq='H')
          
          df4=pd.DataFrame(date_range,columns=['Datee'])
          hourly_data_new['Date']=df4['Datee']
          
          weather1=pd.DataFrame()
          weather1=hourly_data_new
          df5=pd.concat([weather1,df5])
          

#          if('2017' in j):
#           print(j)
# Out:
# ATL
# 2016-1.json
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 2016-10.json
# 2016-11.json
# 2016-12.json
# 2016-2.json
# 2016-3.json
# 2016-4.json
# 2016-5.json
# 2016-6.json
# 2016-7.json
# 2016-8.json
# 2016-9.json
# CLT
# 2016-1.json
# 2016-10.json
# 2016-11.json
# 2016-12.json
# 2016-2.json
# 2016-3.json
# 2016-4.json
# 2016-5.json
# ...

# %%
df6=pd.DataFrame()
for i in os.listdir(path1):
      
       print(i)
      
       for j in os.listdir(path1 + '/' + i):
       
        if('2017' in j):
          print(j)    
          json_string=open(path1 + '/' + i + '/'+ j).read()             #To read a json file as string from path 
          d=json.loads(json_string)

          kk=json_normalize(d['data']['weather'])
          hourly_data=json_normalize(data=d['data']['weather'], record_path='hourly')
          hourly_data_new=hourly_data[['windspeedKmph','DewPointF','cloudcover','precipMM','pressure','WindGustKmph',
                             'visibility','weatherCode','tempF','WindChillF','winddirDegree','humidity','time']]
          
          kk1=json_normalize(d['data']['request'])
          airport_data=kk1[['query']] 
          hourly_data_new['Airport']=i
          date_data=kk[['date']]      
          date_range=pd.date_range(start=date_data['date'][0],periods=744,freq='H')
          
          df4=pd.DataFrame(date_range,columns=['Datee'])
          hourly_data_new['Date']=df4['Datee']
          
          weather1=pd.DataFrame()
          weather1=hourly_data_new
          df6=pd.concat([weather1,df6])
# Out:
# ATL
# 2017-1.json
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 2017-10.json
# 2017-11.json
# 2017-12.json
# 2017-2.json
# 2017-3.json
# 2017-4.json
# 2017-5.json
# 2017-6.json
# 2017-7.json
# 2017-8.json
# 2017-9.json
# CLT
# 2017-1.json
# 2017-10.json
# 2017-11.json
# 2017-12.json
# 2017-2.json
# 2017-3.json
# 2017-4.json
# 2017-5.json
# ...

# %%
df6.shape
# Out:
# (131400, 15)

# %%
df6.tail(5)
# Out:
#     windspeedKmph DewPointF cloudcover precipMM pressure WindGustKmph  \
# 739            14        45          0      0.0     1017           17
# 740            13        45          0      0.0     1017           16
# 741            12        45          0      0.0     1017           14
# 742            12        43          0      0.0     1017           15
# 743            13        42          0      0.0     1017           16
#
#     visibility weatherCode tempF WindChillF winddirDegree humidity  time  \
# 739         10         113    66         65           223       49  1900
# 740         10         113    65         65           222       49  2000
# 741         10         113    65         65           220       49  2100
# 742         10         113    64         64           220       47  2200
# 743         10         113    64         64           220       45  2300
#
#     Airport                Date
# 739     ATL 2017-01-31 19:00:00
# 740     ATL 2017-01-31 20:00:00
# ...

# %%
s=pd.Series(df5['Airport'])
s
s.str.slice(stop=2)
# Out:
# 0      SF
# 1      SF
# 2      SF
# 3      SF
# 4      SF
# 5      SF
# 6      SF
# 7      SF
# 8      SF
# 9      SF
# 10     SF
# 11     SF
# 12     SF
# 13     SF
# 14     SF
# 15     SF
# 16     SF
# 17     SF
# 18     SF
# 19     SF
# 20     SF
# 21     SF
# 22     SF
# 23     SF
# 24     SF
# 25     SF
# 26     SF
# 27     SF
# 28     SF
# 29     SF
#        ..
# 714    AT
# 715    AT
# 716    AT
# 717    AT
# 718    AT
# 719    AT
# 720    AT
# 721    AT
# 722    AT
# 723    AT
# 724    AT
# 725    AT
# 726    AT
# 727    AT
# 728    AT
# 729    AT
# 730    AT
# 731    AT
# 732    AT
# 733    AT
# 734    AT
# 735    AT
# 736    AT
# 737    AT
# 738    AT
# 739    AT
# 740    AT
# 741    AT
# 742    AT
# 743    AT
# Name: Airport, Length: 131760, dtype: object

# %%
os.chdir(r"C:\Users\super\Downloads\WeatherData_new")
df5.to_csv('Weatherdata2016.csv')
df6.to_csv('Weatherdata2017.csv')

# %%
from pandas.io.json import json_normalize

# %%
with open(path) as f:
    d = json.load(f)
from pprint import pprint 
pprint (d)
# Out:
# {'data': {'request': [{'query': 'ATL, Hartsfield-Jackson Atlanta International '
#                                 'Airport, United States of America',
#                        'type': 'IATA'}],
#           'weather': [{'astronomy': [{'moon_illumination': '69',
#                                       'moon_phase': 'Last Quarter',
#                                       'moonrise': '01:52 AM',
#                                       'moonset': '12:42 PM',
#                                       'sunrise': '08:05 AM',
#                                       'sunset': '07:35 PM'}],
#                        'date': '2016-03-01',
#                        'hourly': [{'DewPointC': '8',
#                                    'DewPointF': '46',
#                                    'FeelsLikeC': '13',
#                                    'FeelsLikeF': '55',
#                                    'HeatIndexC': '13',
#                                    'HeatIndexF': '55',
# ...

# %%
hourly_data=json_normalize(data=d['data']['weather'], record_path='hourly')

# %%
hourly_data_new=hourly_data[['windspeedKmph','DewPointF','cloudcover','precipMM','pressure','WindGustKmph',
                             'visibility','weatherCode','tempF','WindChillF','winddirDegree','humidity','time']]

# %%
hourly_data_new
# Out:
#     windspeedKmph DewPointF cloudcover precipMM pressure WindGustKmph  \
# 0               3        46         10      0.0     1020            5
# 1               3        47         21      0.0     1020            5
# 2               3        47         31      0.0     1020            4
# 3               3        48         42      0.0     1019            4
# 4               4        49         53      0.0     1019            6
# 5               4        50         65      0.0     1019            7
# 6               4        51         76      0.0     1019            9
# 7               6        51         74      0.0     1019           10
# 8               7        52         72      0.0     1019           11
# 9               8        52         70      0.0     1019           12
# 10             11        53         49      0.0     1018           14
# 11             13        54         29      0.0     1018           16
# ...

# %%
kk1=json_normalize(d['data']['request'])
airport_data=kk1[['query']]
airport_data.columns
airport_data['query'][0]
# Out:
# 'ATL, Hartsfield-Jackson Atlanta International Airport, United States of America'

# %%
hourly_data_new['Aiport']=airport_data['query'][0]
hourly_data_new
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     windspeedKmph DewPointF cloudcover precipMM pressure WindGustKmph  \
# 0              11        47        100      0.1     1023           17
# 1              13        44        100      0.0     1023           22
# 2              14        41        100      0.0     1023           26
# 3              16        38        100      0.0     1023           30
# 4              17        38        100      0.0     1023           30
# 5              17        38        100      0.0     1024           29
# 6              18        38        100      0.0     1024           28
# ...

# %%
date_data=kk[['date']]
date_data
# Out:
#           date
# 0   2016-01-01
# 1   2016-01-02
# 2   2016-01-03
# 3   2016-01-04
# 4   2016-01-05
# 5   2016-01-06
# 6   2016-01-07
# 7   2016-01-08
# 8   2016-01-09
# 9   2016-01-10
# 10  2016-01-11
# 11  2016-01-12
# 12  2016-01-13
# 13  2016-01-14
# 14  2016-01-15
# 15  2016-01-16
# 16  2016-01-17
# 17  2016-01-18
# 18  2016-01-19
# 19  2016-01-20
# 20  2016-01-21
# 21  2016-01-22
# 22  2016-01-23
# 23  2016-01-24
# 24  2016-01-25
# 25  2016-01-26
# 26  2016-01-27
# 27  2016-01-28
# 28  2016-01-29
# 29  2016-01-30
# 30  2016-01-31

# %%
from datetime import datetime
date_range=pd.date_range(start=date_data['date'][0],periods=744,freq='H')
df4=pd.DataFrame()
df4=pd.DataFrame(date_range,columns=['Datee'])
df4
# Out:
#                   Datee
# 0   2016-02-01 00:00:00
# 1   2016-02-01 01:00:00
# 2   2016-02-01 02:00:00
# 3   2016-02-01 03:00:00
# 4   2016-02-01 04:00:00
# 5   2016-02-01 05:00:00
# 6   2016-02-01 06:00:00
# 7   2016-02-01 07:00:00
# 8   2016-02-01 08:00:00
# 9   2016-02-01 09:00:00
# 10  2016-02-01 10:00:00
# 11  2016-02-01 11:00:00
# 12  2016-02-01 12:00:00
# 13  2016-02-01 13:00:00
# 14  2016-02-01 14:00:00
# 15  2016-02-01 15:00:00
# 16  2016-02-01 16:00:00
# 17  2016-02-01 17:00:00
# 18  2016-02-01 18:00:00
# 19  2016-02-01 19:00:00
# 20  2016-02-01 20:00:00
# 21  2016-02-01 21:00:00
# 22  2016-02-01 22:00:00
# 23  2016-02-01 23:00:00
# 24  2016-02-02 00:00:00
# 25  2016-02-02 01:00:00
# 26  2016-02-02 02:00:00
# 27  2016-02-02 03:00:00
# 28  2016-02-02 04:00:00
# 29  2016-02-02 05:00:00
# ..                  ...
# 714 2016-03-01 18:00:00
# 715 2016-03-01 19:00:00
# 716 2016-03-01 20:00:00
# 717 2016-03-01 21:00:00
# 718 2016-03-01 22:00:00
# 719 2016-03-01 23:00:00
# ...

# %%
hourly_data_new['Date']=df2['Date']
hourly_data_new
weather1=hourly_data_new
weather1
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     windspeedKmph DewPointF cloudcover precipMM pressure WindGustKmph  \
# 0              11        47        100      0.1     1023           17
# 1              13        44        100      0.0     1023           22
# 2              14        41        100      0.0     1023           26
# 3              16        38        100      0.0     1023           30
# 4              17        38        100      0.0     1023           30
# 5              17        38        100      0.0     1024           29
# 6              18        38        100      0.0     1024           28
# ...

# %%
df1=df[['Year','Quarter','Month','DayofMonth','FlightDate','DepTime','DepDel15','Origin','Dest',
        'CRSDepTime','DepDelayMinutes','OriginAirportID','DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e37da5cc38c8> in <module>
# ----> 1 df1=df[['Year','Quarter','Month','DayofMonth','FlightDate','DepTime','DepDel15','Origin','Dest',
#       2         'CRSDepTime','DepDelayMinutes','OriginAirportID','DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes']]
#
# NameError: name 'df' is not defined

# %%
df1
# Out:
#         Year  Quarter  Month  DayofMonth  FlightDate  DepTime  DepDel15  \
# 0       2016        1      1           6  2016-01-06   1057.0       0.0
# 1       2016        1      1           7  2016-01-07   1056.0       0.0
# 2       2016        1      1           8  2016-01-08   1055.0       0.0
# 3       2016        1      1           9  2016-01-09   1102.0       0.0
# 4       2016        1      1          10  2016-01-10   1240.0       1.0
# 5       2016        1      1          11  2016-01-11   1107.0       0.0
# 6       2016        1      1          12  2016-01-12   1059.0       0.0
# 7       2016        1      1          13  2016-01-13   1055.0       0.0
# 8       2016        1      1          14  2016-01-14   1058.0       0.0
# 9       2016        1      1          15  2016-01-15   1056.0       0.0
# 10      2016        1      1          16  2016-01-16   1056.0       0.0
# 11      2016        1      1          17  2016-01-17   1053.0       0.0
# ...

# %%
import os
import glob
import pandas as pd
os.chdir(r"C:\Users\super\Downloads\flight2016")
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
all_filenames
# glob.glob('*.csv')
# os.listdir(r"C:\Users\super\Downloads\flight2016")
# Out:
# ['On_Time_On_Time_Performance_2016_1.csv',
#  'On_Time_On_Time_Performance_2016_10.csv',
#  'On_Time_On_Time_Performance_2016_11.csv',
#  'On_Time_On_Time_Performance_2016_12.csv',
#  'On_Time_On_Time_Performance_2016_2.csv',
#  'On_Time_On_Time_Performance_2016_3.csv',
#  'On_Time_On_Time_Performance_2016_4.csv',
#  'On_Time_On_Time_Performance_2016_5.csv',
#  'On_Time_On_Time_Performance_2016_6.csv',
#  'On_Time_On_Time_Performance_2016_7.csv',
#  'On_Time_On_Time_Performance_2016_8.csv',
#  'On_Time_On_Time_Performance_2016_9.csv']

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig',low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-602c4f7653ff> in <module>
#       2 combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#       3 #export to csv
# ----> 4 combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig',low_memory=False)
#
# TypeError: to_csv() got an unexpected keyword argument 'low_memory'

# %%
combined_csv
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2016        1      1           6          3  2016-01-06            AA
# 1       2016        1      1           7          4  2016-01-07            AA
# 2       2016        1      1           8          5  2016-01-08            AA
# 3       2016        1      1           9          6  2016-01-09            AA
# 4       2016        1      1          10          7  2016-01-10            AA
# 5       2016        1      1          11          1  2016-01-11            AA
# 6       2016        1      1          12          2  2016-01-12            AA
# 7       2016        1      1          13          3  2016-01-13            AA
# 8       2016        1      1          14          4  2016-01-14            AA
# 9       2016        1      1          15          5  2016-01-15            AA
# 10      2016        1      1          16          6  2016-01-16            AA
# ...

# %%
os.chdir(r"C:\Users\super\Downloads\flight2017")
extension = 'csv'
all_filenames2 = [i for i in glob.glob('*.{}'.format(extension))]
all_filenames2
# Out:
# ['On_Time_On_Time_Performance_2017_1.csv',
#  'On_Time_On_Time_Performance_2017_10.csv',
#  'On_Time_On_Time_Performance_2017_11.csv',
#  'On_Time_On_Time_Performance_2017_12.csv',
#  'On_Time_On_Time_Performance_2017_2.csv',
#  'On_Time_On_Time_Performance_2017_3.csv',
#  'On_Time_On_Time_Performance_2017_4.csv',
#  'On_Time_On_Time_Performance_2017_5.csv',
#  'On_Time_On_Time_Performance_2017_6.csv',
#  'On_Time_On_Time_Performance_2017_7.csv',
#  'On_Time_On_Time_Performance_2017_8.csv',
#  'On_Time_On_Time_Performance_2017_9.csv']

# %%
#combine all files in the list
combined_csv2 = pd.concat([pd.read_csv(f) for f in all_filenames2 ])
#export to csv
combined_csv2.to_csv( "combined_csv2.csv", index=False, encoding='utf-8-sig',low_memory=False)
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3185: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# C:\Users\super\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3185: DtypeWarning: Columns (48,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# C:\Users\super\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3185: DtypeWarning: Columns (77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-d1f1e79a4441> in <module>
#       2 combined_csv2 = pd.concat([pd.read_csv(f) for f in all_filenames2 ])
# ...

# %%
combined_csv2
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2017        1      1          17          2  2017-01-17            AA
# 1       2017        1      1          18          3  2017-01-18            AA
# 2       2017        1      1          19          4  2017-01-19            AA
# 3       2017        1      1          20          5  2017-01-20            AA
# 4       2017        1      1          21          6  2017-01-21            AA
# 5       2017        1      1          22          7  2017-01-22            AA
# 6       2017        1      1          23          1  2017-01-23            AA
# 7       2017        1      1          24          2  2017-01-24            AA
# 8       2017        1      1          25          3  2017-01-25            AA
# 9       2017        1      1          26          4  2017-01-26            AA
# 10      2017        1      1          27          5  2017-01-27            AA
# ...

# %%
import os
import glob
import pandas as pd
os.chdir(r"C:\Users\super\Downloads\flight2016")
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
all_filenames
# Out:
# ['On_Time_On_Time_Performance_2016_1.csv',
#  'On_Time_On_Time_Performance_2016_10.csv',
#  'On_Time_On_Time_Performance_2016_11.csv',
#  'On_Time_On_Time_Performance_2016_12.csv',
#  'On_Time_On_Time_Performance_2016_2.csv',
#  'On_Time_On_Time_Performance_2016_3.csv',
#  'On_Time_On_Time_Performance_2016_4.csv',
#  'On_Time_On_Time_Performance_2016_5.csv',
#  'On_Time_On_Time_Performance_2016_6.csv',
#  'On_Time_On_Time_Performance_2016_7.csv',
#  'On_Time_On_Time_Performance_2016_8.csv',
#  'On_Time_On_Time_Performance_2016_9.csv']

# %%
df=pd.read_csv("On_Time_On_Time_Performance_2016_1.csv")
df
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (77) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2016        1      1           6          3  2016-01-06            AA
# 1       2016        1      1           7          4  2016-01-07            AA
# 2       2016        1      1           8          5  2016-01-08            AA
# 3       2016        1      1           9          6  2016-01-09            AA
# 4       2016        1      1          10          7  2016-01-10            AA
# 5       2016        1      1          11          1  2016-01-11            AA
# 6       2016        1      1          12          2  2016-01-12            AA
# 7       2016        1      1          13          3  2016-01-13            AA
# ...

# %%
df1=df[['Year','Quarter','Month','DayofMonth','FlightDate','DepTime','DepDel15','Origin','Dest',
        'CRSDepTime','DepDelayMinutes','OriginAirportID','DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes']]

# %%
df2=pd.DataFrame()
array=['ATL','CLT','DEN','DFW','EWR','IAH','JFK','LAS','LAX','MCO','MIA','ORD','PHX','SEA','SFO']
for filename in all_filenames:
    df=pd.read_csv(filename)    
    df1=df.loc[df['Origin'].isin(array) & df['Dest'].isin(array)]
    df1=df1[['Year','Quarter','Month','DayofMonth','FlightDate','DepTime','DepDel15','Origin','Dest','CRSDepTime','DepDelayMinutes','OriginAirportID','DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes']]
    df2=pd.concat([df1,df2])
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (77) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\super\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\super\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (48,69,76,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\super\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (77,84) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
df2
# Out:
#         Year  Quarter  Month  DayofMonth  FlightDate  DepTime  DepDel15  \
# 17      2016        3      9           1  2016-09-01    827.0       0.0
# 18      2016        3      9           2  2016-09-02    828.0       0.0
# 19      2016        3      9           4  2016-09-04    823.0       0.0
# 20      2016        3      9           5  2016-09-05    827.0       0.0
# 21      2016        3      9           6  2016-09-06    826.0       0.0
# 22      2016        3      9           7  2016-09-07    823.0       0.0
# 23      2016        3      9           8  2016-09-08    826.0       0.0
# 24      2016        3      9           9  2016-09-09    829.0       0.0
# 25      2016        3      9          10  2016-09-10    825.0       0.0
# 26      2016        3      9          11  2016-09-11    822.0       0.0
# 27      2016        3      9          12  2016-09-12    827.0       0.0
# 28      2016        3      9          13  2016-09-13    826.0       0.0
# ...

# %%
df2.shape
# Out:
# (948819, 17)

# %%
df3=pd.DataFrame()
array=['ATL','CLT','DEN','DFW','EWR','IAH','JFK','LAS','LAX','MCO','MIA','ORD','PHX','SEA','SFO']
for filename in all_filenames2:
    df=pd.read_csv(filename)
    df1=df.loc[df['Origin'].isin(array) & df['Dest'].isin(array)]
    df1=df1[['Year','Quarter','Month','DayofMonth','FlightDate','DepTime','DepDel15','Origin','Dest','CRSDepTime','DepDelayMinutes','OriginAirportID','DestAirportID','ArrTime','CRSArrTime','ArrDel15','ArrDelayMinutes']]
    
    
    df3=pd.concat([df1,df3])
# Out:
# C:\Users\super\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (48,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df3.shape
# Out:
# (928477, 17)

# %%
df2.to_csv('Flightdata2016.csv')
df3.to_csv('Flightdata2017.csv')

# %%
pwd
# Out:
# 'C:\\Users\\super\\Downloads\\flight2017'

# %%
df2
# Out:
#         Year  Quarter  Month  DayofMonth  FlightDate  DepTime  DepDel15  \
# 17      2016        3      9           1  2016-09-01    827.0       0.0
# 18      2016        3      9           2  2016-09-02    828.0       0.0
# 19      2016        3      9           4  2016-09-04    823.0       0.0
# 20      2016        3      9           5  2016-09-05    827.0       0.0
# 21      2016        3      9           6  2016-09-06    826.0       0.0
# 22      2016        3      9           7  2016-09-07    823.0       0.0
# 23      2016        3      9           8  2016-09-08    826.0       0.0
# 24      2016        3      9           9  2016-09-09    829.0       0.0
# 25      2016        3      9          10  2016-09-10    825.0       0.0
# 26      2016        3      9          11  2016-09-11    822.0       0.0
# 27      2016        3      9          12  2016-09-12    827.0       0.0
# 28      2016        3      9          13  2016-09-13    826.0       0.0
# ...
